# %%
import pandas as pd
import csv
import numpy as np

# %%
nfl_stats = "nfl_stats.csv"

# %%
nfl_stats_df = pd.read_csv(nfl_stats)

# %%
nfl_stats_df.head()
# Out:
#                      Player Pos  Year  Week Team Opponent Abbrev        Date  \
# 0             Aaron Rodgers  QB  2019     1  GNB             CHI  2019-09-05
# 1               Aaron Jones  RB  2019     1  GNB             CHI  2019-09-05
# 2  Marquez Valdes-Scantling  WR  2019     1  GNB             CHI  2019-09-05
# 3             Davante Adams  WR  2019     1  GNB             CHI  2019-09-05
# 4              Jimmy Graham  TE  2019     1  GNB             CHI  2019-09-05
#
#         Game ID H/A   OT  ...  Def Pct  ST Num  ST Pct    DKP  DKSalary  \
# 0  201909050chi   A  NaN  ...       0%       0      0%  12.92    6500.0
# 1  201909050chi   A  NaN  ...       0%       0      0%   4.90    5400.0
# 2  201909050chi   A  NaN  ...       0%       0      0%   9.20    4400.0
# 3  201909050chi   A  NaN  ...       0%       0      0%   7.60    7700.0
# 4  201909050chi   A  NaN  ...       0%       0      0%  12.00    3600.0
#
#      FDP FDSalary DK_Total_FP FD_Total_FP  YH_Total_FP
# ...

# %%
nfl_stats_df.describe()
# Out:
#          Year         Week   Team Score  Opponent Score       Spread  \
# count  5340.0  5340.000000  5340.000000     5340.000000  5340.000000
# mean   2019.0     9.082022    23.039513       22.758427     0.568352
# std       0.0     5.009489    10.326009       10.184277    13.613584
# min    2019.0     1.000000     0.000000        0.000000   -49.000000
# 25%    2019.0     5.000000    16.000000       16.000000    -5.000000
# 50%    2019.0     9.000000    23.000000       23.000000    -1.000000
# 75%    2019.0    14.000000    30.000000       30.000000     5.000000
# max    2019.0    17.000000    59.000000       59.000000    70.000000
#
#         Over/Under  Implied Points  Actual Margin  Temperature         Wind  \
# count  5340.000000     5340.000000    5340.000000  3760.000000  3760.000000
# mean     45.293352       22.362500      -0.281086    60.786436     8.265426
# std       4.424064        6.946817      15.150905    16.583689     4.636368
# ...
